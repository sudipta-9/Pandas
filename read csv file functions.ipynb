# %% [markdown]
# # Read CSV file

# %%
import pandas as pd
csv1 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv")
csv1
# Out:
#     id   firstname   lastname                        email  \
# 0   25       Helsa      Weide      Helsa.Weide@yopmail.com
# 1   26    Sheelagh      Grosz   Sheelagh.Grosz@yopmail.com
# 2   27      Dorice    Skurnik   Dorice.Skurnik@yopmail.com
# 3   28        Jean    Colleen     Jean.Colleen@yopmail.com
# 4   29       Ketti     Harday     Ketti.Harday@yopmail.com
# 5   30         Ira      Olnee        Ira.Olnee@yopmail.com
# 6   31      Allyce     Mallon    Allyce.Mallon@yopmail.com
# 7   32      Jackie      Anyah     Jackie.Anyah@yopmail.com
# 8   33    Pierette        Old     Pierette.Old@yopmail.com
# 9   34      Zondra      Tryck     Zondra.Tryck@yopmail.com
# 10  35       Karly      Izaak      Karly.Izaak@yopmail.com
# 11  36       Aaren     Ammann     Aaren.Ammann@yopmail.com
# 12  37    Mathilda      Jarib   Mathilda.Jarib@yopmail.com
# 13  38      Corene      Berne     Corene.Berne@yopmail.com
# 14  39       Liana  Laurianne  Liana.Laurianne@yopmail.com
# ...

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",nrows=1)
csv2
# Out:
#    id firstname lastname                    email                 email2  \
# 0  25     Helsa    Weide  Helsa.Weide@yopmail.com  Helsa.Weide@gmail.com
#
#   profession
# 0     worker

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",nrows=1)
print(type(csv2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",nrows=3)
csv2
# Out:
#    id firstname lastname                       email  \
# 0  25     Helsa    Weide     Helsa.Weide@yopmail.com
# 1  26  Sheelagh    Grosz  Sheelagh.Grosz@yopmail.com
# 2  27    Dorice  Skurnik  Dorice.Skurnik@yopmail.com
#
#                      email2      profession
# 0     Helsa.Weide@gmail.com          worker
# 1  Sheelagh.Grosz@gmail.com       developer
# 2  Dorice.Skurnik@gmail.com  police officer

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",usecols=["firstname"])
csv2
# Out:
#      firstname
# 0        Helsa
# 1     Sheelagh
# 2       Dorice
# 3         Jean
# 4        Ketti
# 5          Ira
# 6       Allyce
# 7       Jackie
# 8     Pierette
# 9       Zondra
# 10       Karly
# 11       Aaren
# 12    Mathilda
# 13      Corene
# 14       Liana
# 15         Flo
# 16     Damaris
# 17     Damaris
# 18   Christian
# 19     Iseabal
# 20      Elmira
# 21    Beverley
# 22      Lonnie
# 23  Gabriellia
# 24       Loree

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",usecols=["firstname","profession"])
csv2
# Out:
#      firstname      profession
# 0        Helsa          worker
# 1     Sheelagh       developer
# 2       Dorice  police officer
# 3         Jean  police officer
# 4        Ketti       developer
# 5          Ira       developer
# 6       Allyce  police officer
# 7       Jackie       developer
# 8     Pierette  police officer
# 9       Zondra     firefighter
# 10       Karly          doctor
# 11       Aaren  police officer
# 12    Mathilda          doctor
# 13      Corene       developer
# 14       Liana  police officer
# 15         Flo          worker
# 16     Damaris       developer
# 17     Damaris  police officer
# 18   Christian  police officer
# 19     Iseabal          worker
# 20      Elmira          doctor
# 21    Beverley  police officer
# 22      Lonnie          doctor
# 23  Gabriellia          doctor
# 24       Loree       developer

# %%
csv2 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",usecols=[0,2])
csv2
# Out:
#     id   lastname
# 0   25      Weide
# 1   26      Grosz
# 2   27    Skurnik
# 3   28    Colleen
# 4   29     Harday
# 5   30      Olnee
# 6   31     Mallon
# 7   32      Anyah
# 8   33        Old
# 9   34      Tryck
# 10  35      Izaak
# 11  36     Ammann
# 12  37      Jarib
# 13  38      Berne
# 14  39  Laurianne
# 15  40     Prober
# 16  41      Carri
# 17  42        Dex
# 18  43      Helve
# 19  44     Mayeda
# 20  45     Hashim
# 21  46      Diann
# 22  47      Danby
# 23  48        Fry
# 24  49     Letsou

# %%
csv3 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",skiprows=[0])
csv3
# Out:
#     25       Helsa      Weide      Helsa.Weide@yopmail.com  \
# 0   26    Sheelagh      Grosz   Sheelagh.Grosz@yopmail.com
# 1   27      Dorice    Skurnik   Dorice.Skurnik@yopmail.com
# 2   28        Jean    Colleen     Jean.Colleen@yopmail.com
# 3   29       Ketti     Harday     Ketti.Harday@yopmail.com
# 4   30         Ira      Olnee        Ira.Olnee@yopmail.com
# 5   31      Allyce     Mallon    Allyce.Mallon@yopmail.com
# 6   32      Jackie      Anyah     Jackie.Anyah@yopmail.com
# 7   33    Pierette        Old     Pierette.Old@yopmail.com
# 8   34      Zondra      Tryck     Zondra.Tryck@yopmail.com
# 9   35       Karly      Izaak      Karly.Izaak@yopmail.com
# 10  36       Aaren     Ammann     Aaren.Ammann@yopmail.com
# 11  37    Mathilda      Jarib   Mathilda.Jarib@yopmail.com
# 12  38      Corene      Berne     Corene.Berne@yopmail.com
# 13  39       Liana  Laurianne  Liana.Laurianne@yopmail.com
# 14  40         Flo     Prober       Flo.Prober@yopmail.com
# ...

# %%
csv4 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",index_col="firstname")
csv4
# Out:
#             id   lastname                        email  \
# firstname
# Helsa       25      Weide      Helsa.Weide@yopmail.com
# Sheelagh    26      Grosz   Sheelagh.Grosz@yopmail.com
# Dorice      27    Skurnik   Dorice.Skurnik@yopmail.com
# Jean        28    Colleen     Jean.Colleen@yopmail.com
# Ketti       29     Harday     Ketti.Harday@yopmail.com
# Ira         30      Olnee        Ira.Olnee@yopmail.com
# Allyce      31     Mallon    Allyce.Mallon@yopmail.com
# Jackie      32      Anyah     Jackie.Anyah@yopmail.com
# Pierette    33        Old     Pierette.Old@yopmail.com
# Zondra      34      Tryck     Zondra.Tryck@yopmail.com
# Karly       35      Izaak      Karly.Izaak@yopmail.com
# Aaren       36     Ammann     Aaren.Ammann@yopmail.com
# Mathilda    37      Jarib   Mathilda.Jarib@yopmail.com
# Corene      38      Berne     Corene.Berne@yopmail.com
# Liana       39  Laurianne  Liana.Laurianne@yopmail.com
# Flo         40     Prober       Flo.Prober@yopmail.com
# ...

# %%
csv5 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",header=2)
csv5
# Out:
#     26    Sheelagh      Grosz   Sheelagh.Grosz@yopmail.com  \
# 0   27      Dorice    Skurnik   Dorice.Skurnik@yopmail.com
# 1   28        Jean    Colleen     Jean.Colleen@yopmail.com
# 2   29       Ketti     Harday     Ketti.Harday@yopmail.com
# 3   30         Ira      Olnee        Ira.Olnee@yopmail.com
# 4   31      Allyce     Mallon    Allyce.Mallon@yopmail.com
# 5   32      Jackie      Anyah     Jackie.Anyah@yopmail.com
# 6   33    Pierette        Old     Pierette.Old@yopmail.com
# 7   34      Zondra      Tryck     Zondra.Tryck@yopmail.com
# 8   35       Karly      Izaak      Karly.Izaak@yopmail.com
# 9   36       Aaren     Ammann     Aaren.Ammann@yopmail.com
# 10  37    Mathilda      Jarib   Mathilda.Jarib@yopmail.com
# 11  38      Corene      Berne     Corene.Berne@yopmail.com
# 12  39       Liana  Laurianne  Liana.Laurianne@yopmail.com
# 13  40         Flo     Prober       Flo.Prober@yopmail.com
# 14  41     Damaris      Carri    Damaris.Carri@yopmail.com
# ...

# %%
csv4 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",names=["col1","col2","col3","col4","col5"])
csv4
# Out:
#           col1       col2                         col3  \
# id   firstname   lastname                        email
# 25       Helsa      Weide      Helsa.Weide@yopmail.com
# 26    Sheelagh      Grosz   Sheelagh.Grosz@yopmail.com
# 27      Dorice    Skurnik   Dorice.Skurnik@yopmail.com
# 28        Jean    Colleen     Jean.Colleen@yopmail.com
# 29       Ketti     Harday     Ketti.Harday@yopmail.com
# 30         Ira      Olnee        Ira.Olnee@yopmail.com
# 31      Allyce     Mallon    Allyce.Mallon@yopmail.com
# 32      Jackie      Anyah     Jackie.Anyah@yopmail.com
# 33    Pierette        Old     Pierette.Old@yopmail.com
# 34      Zondra      Tryck     Zondra.Tryck@yopmail.com
# 35       Karly      Izaak      Karly.Izaak@yopmail.com
# 36       Aaren     Ammann     Aaren.Ammann@yopmail.com
# 37    Mathilda      Jarib   Mathilda.Jarib@yopmail.com
# 38      Corene      Berne     Corene.Berne@yopmail.com
# 39       Liana  Laurianne  Liana.Laurianne@yopmail.com
# ...

# %%
csv5 = pd.read_csv("D:\\Projects\\Pandas\\Test.csv",dtype={"id":"float"})
csv5
# Out:
#    id\tfirstname\tlastname\temail\temail2\tprofession
# 0   25\tHelsa\tWeide\tHelsa.Weide@yopmail.com\tHel...
# 1   26\tSheelagh\tGrosz\tSheelagh.Grosz@yopmail.co...
# 2   27\tDorice\tSkurnik\tDorice.Skurnik@yopmail.co...
# 3   28\tJean\tColleen\tJean.Colleen@yopmail.com\tJ...
# 4   29\tKetti\tHarday\tKetti.Harday@yopmail.com\tK...
# 5   30\tIra\tOlnee\tIra.Olnee@yopmail.com\tIra.Oln...
# 6   31\tAllyce\tMallon\tAllyce.Mallon@yopmail.com\...
# 7   32\tJackie\tAnyah\tJackie.Anyah@yopmail.com\tJ...
# 8   33\tPierette\tOld\tPierette.Old@yopmail.com\tP...
# 9   34\tZondra\tTryck\tZondra.Tryck@yopmail.com\tZ...
# 10  35\tKarly\tIzaak\tKarly.Izaak@yopmail.com\tKar...
# 11  36\tAaren\tAmmann\tAaren.Ammann@yopmail.com\tA...
# 12  37\tMathilda\tJarib\tMathilda.Jarib@yopmail.co...
# 13  38\tCorene\tBerne\tCorene.Berne@yopmail.com\tC...
# 14  39\tLiana\tLaurianne\tLiana.Laurianne@yopmail....
# 15  40\tFlo\tProber\tFlo.Prober@yopmail.com\tFlo.P...
# ...
